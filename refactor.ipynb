# %% [markdown]
# ## Refactor code for mass calculator
#
# The code in MassCalculator.py is old and embarrasing, so I would like to refactor it. This will give me the opportunity to determine if I want to do anything else with it.
#
# I would like to write the new script with TDD in mind, and write tests as soon as I dredge up the script's original functionality.

# %% [markdown]
# #### functionality
#
# What functionality should the refurbished script have? Here are a list of functions from the original script:

# %%
"""
Function/Module/Method List:
    Module main()
    Module welcome(string user_name)
    Module help_me()
    Module goodbye(string user_name)
    Module input_again(string invalid_input)
    Function string accept_user_input(string prompt, string in_type)    
    Function array parse_formula(string full_formula)
    Function real calculate_subtotal(array parsed_formula)    
    Function Boolean verify_help_input(string help_input)  
    Function int atom_quantity(string name)
    Function real mol_count(string formula)  
    Function real calculate_product(real num1, real num2)
    Function string generate_formula(string partial_formula, string atomic_symbol, quantity)
For Class ElementData:
    Module string get_symbols()
    Method string get_name(int atomic_number)
    Method real get_mass(int atomic_number)
For Class Verify:
    Method Boolean verify_symbol_input(string symbol_input)
    Method Boolean verify_qty_input(string atm_quantity_input)
    Method Boolean verify_mol_input(string mol_input)
    Method Boolean verify_formula_input(array parsed_formula)
    """

_ = '_'

# %% [markdown]
# Things this app can do:
# * welcome user
# * display help menu with key commands
# * collect, validate chemical formula input
# * parse formula
# * calculate subtotal
# * validate help menu input
# * determine molecular mass
#
# This shows us that the program logic is pretty convoluted. I think an entire rewrite might be faster than trying to work towards a better structure.

# %%
#generate element subclasses
name_data = [
    "Null", "Hydrogen", "Helium", "Lithium", "Beryllium", "Boron", "Carbon", "Nitrogen", "Oxygen", "Fluorine", "Neon", "Sodium", "Magnesium", "Aluminum", "Silicon", "Phosphorous", "Sulfur", "Chlorine", "Argon", "Potassium", "Calcium", "Scandium", "Titanium", "Vanadium", "Chromium", "Manganese", "Iron", "Cobalt", "Nickel", "Copper", "Zinc", "Gallium", "Germanium", "Arsenic", "Selenium", "Bromine", "Krypton", "Rubidium", "Strontium", "Yttrium", "Zirconium", "Niobium", "Molybdenum", "Technetium", "Ruthenium", "Rhodium", "Palladium", "Silver", "Cadmium", "Indium", "Tin", "Antimony", "Tellurium", "Iodine", "Xenon", "Cesium", "Barium", "Lanthanum", "Cerium", "Praseodymium", "Neodymium", "Promethium", "Samarium", "Europium", "Gadolinium", "Terbium", "Dysprosium", "Holmium", "Erbium", "Thulium", "Ytterbium", "Lutetium", "Hafnium", "Tantalum", "Tungsten", "Rhenium", "Osmium", "Iridium", "Platinum", "Gold", "Mercury", "Thallium", "Lead", "Bismuth", "Polonium", "Astatine", "Radon", "Francium", "Radon", "Actinium", "Thorium", "Protactinium", "Uranium", "Neptunium", "Plutonium", "Americium", "Curium", "Berkelium", "Californium", "Einsteinium", "Fermium", "Mendelevium", "Nobelium", "Lawrencium", "Rutherfordium", "Dubnium", "Seaborgium", "Bohrium", "Hassium", "Meitnerium", "Darmstadtium", "Roentgenium", "Copernicium", "Ununtrium", "Flerovium", "Ununpentium", "Livermorium", "Ununseptium", "Ununoctium"]
mass_data = [
    0.0, 1.007, 4.002, 6.938, 9.012, 10.806, 12.0096, 14.006, 15.999, 18.998, 20.1797, 22.989, 24.304, 26.981, 28.084, 30.973, 32.059, 35.446, 39.948, 39.0983, 40.078, 44.955, 47.867, 50.9415, 51.9961, 54.938, 55.845, 58.933, 58.6934, 63.546, 65.38, 69.723, 72.630, 74.921, 78.971, 79.901, 83.798, 85.4678, 87.62, 88.905, 91.224, 92.906, 95.95, 98.0, 101.07, 102.905, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.760, 127.60, 126.904, 131.293, 132.905, 137.327, 138.905, 140.116, 140.907, 144.242, 145, 150.36, 151.964, 157.25, 158.925, 162.500, 164.930, 167.259, 168.934, 173.054, 174.9668, 178.49, 180.947, 183.84, 186.207, 190.23, 192.217, 195.084, 196.966, 200.592, 204.382, 207.2, 208.980, 209, 210, 222, 223, 226, 227, 232.037, 231.035, 238.028, 237, 244, 243, 247, 247, 251, 252, 257, 258, 259, 262, 267, 268, 271, 272, 270, 276, 281, 280, 285, 284, 289, 288, 293, 294, 294]
    
symbol_data = ["done", "H", "He", "Li", "Be", "B", "C", "N", "O", "F", "Ne", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "Ar", "K", "Ca", "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Kr","Rb", "Sr", "Y", "Zr", "Nb", "Mo", "Tc", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I", "Xe", "Cs", "Ba", "La", "Ce", "Pr", "Nd", "Pm", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt", "Au", "Hg", "Tl", "Pb", "Bi", "Po", "At", "Rn", "Fr", "Ra", "Ac", "Th", "Pa", "U", "Np", "Pu", "Am", "Cm", "Bk", "Cf", "Es", "Fm", "Md", "No", "Lr", "Rf", "Db", "Sg", "Bh", "Hs", "Mt", "Ds", "Rg", "Cn", "Uut", "Fl", "Uup", "Lv", "Uus", "Uuo"]

for index, name in enumerate(name_data):
    print('class {}(Element):'.format(name))
    print('    def __init__(self):')
    print("        super().__init__('{}', '{}', {}, {})".format(name, symbol_data[index], index, mass_data[index]))
    print("        self.label = ''")
    print()
    print()
# Out:
# class Null(Element):
#     def __init__(self):
#         super().__init__('Null', 'done', 0, 0.0)
#         self.label = ''
#
#
# class Hydrogen(Element):
#     def __init__(self):
#         super().__init__('Hydrogen', 'H', 1, 1.007)
#         self.label = ''
#
#
# class Helium(Element):
#     def __init__(self):
#         super().__init__('Helium', 'He', 2, 4.002)
#         self.label = ''
#
#
# class Lithium(Element):
#     def __init__(self):
#         super().__init__('Lithium', 'Li', 3, 6.938)
#         self.label = ''
#
#
# class Beryllium(Element):
#     def __init__(self):
#         super().__init__('Beryllium', 'Be', 4, 9.012)
#         self.label = ''
#
#
# class Boron(Element):
#     def __init__(self):
#         super().__init__('Boron', 'B', 5, 10.806)
#         self.label = ''
#
#
# class Carbon(Element):
#     def __init__(self):
#         super().__init__('Carbon', 'C', 6, 12.0096)
#         self.label = ''
#
#
# class Nitrogen(Element):
#     def __init__(self):
# ...

# %%
class Element:
    def __init__(self, name, symbol, number, mass):
        self.name = name
        self.symbol = symbol
        self.number = number
        self.mass = mass


class Hydrogen(Element):
    def __init__(self):
        super().__init__('Hydrogen', 'H', 1, 1.008)

        
class Helium(Element):
    def __init__(self):
        super().__init__('Helium', 'He', 2, 4.0026)


class Lithium(Element):
    def __init__(self):
        super().__init__('Lithium', 'Li', 3, 6.94)


class Beryllium(Element):
    def __init__(self):
        super().__init__('Beryllium', 'Be', 4, 9.0122)


class Boron(Element):
    def __init__(self):
        super().__init__('Boron', 'B', 5, 10.81)


class Carbon(Element):
    def __init__(self):
        super().__init__('Carbon', 'C', 6, 12.0096)


class Nitrogen(Element):
    def __init__(self):
        super().__init__('Nitrogen', 'N', 7, 14.006)


class Oxygen(Element):
    def __init__(self):
        super().__init__('Oxygen', 'O', 8, 15.999)


class Fluorine(Element):
    def __init__(self):
        super().__init__('Fluorine', 'F', 9, 18.998)


class Neon(Element):
    def __init__(self):
        super().__init__('Neon', 'Ne', 10, 20.1797)


class Sodium(Element):
    def __init__(self):
        super().__init__('Sodium', 'Na', 11, 22.989)


class Magnesium(Element):
    def __init__(self):
        super().__init__('Magnesium', 'Mg', 12, 24.304)


class Aluminum(Element):
    def __init__(self):
        super().__init__('Aluminum', 'Al', 13, 26.981)


class Silicon(Element):
    def __init__(self):
        super().__init__('Silicon', 'Si', 14, 28.084)


class Phosphorous(Element):
    def __init__(self):
        super().__init__('Phosphorous', 'P', 15, 30.973)


class Sulfur(Element):
    def __init__(self):
        super().__init__('Sulfur', 'S', 16, 32.059)


class Chlorine(Element):
    def __init__(self):
        super().__init__('Chlorine', 'Cl', 17, 35.446)


class Argon(Element):
    def __init__(self):
        super().__init__('Argon', 'Ar', 18, 39.948)


class Potassium(Element):
    def __init__(self):
        super().__init__('Potassium', 'K', 19, 39.0983)


class Calcium(Element):
    def __init__(self):
        super().__init__('Calcium', 'Ca', 20, 40.078)


class Scandium(Element):
    def __init__(self):
        super().__init__('Scandium', 'Sc', 21, 44.955)


class Titanium(Element):
    def __init__(self):
        super().__init__('Titanium', 'Ti', 22, 47.867)


class Vanadium(Element):
    def __init__(self):
        super().__init__('Vanadium', 'V', 23, 50.9415)


class Chromium(Element):
    def __init__(self):
        super().__init__('Chromium', 'Cr', 24, 51.9961)


class Manganese(Element):
    def __init__(self):
        super().__init__('Manganese', 'Mn', 25, 54.938)


class Iron(Element):
    def __init__(self):
        super().__init__('Iron', 'Fe', 26, 55.845)


class Cobalt(Element):
    def __init__(self):
        super().__init__('Cobalt', 'Co', 27, 58.933)


class Nickel(Element):
    def __init__(self):
        super().__init__('Nickel', 'Ni', 28, 58.6934)


class Copper(Element):
    def __init__(self):
        super().__init__('Copper', 'Cu', 29, 63.546)


class Zinc(Element):
    def __init__(self):
        super().__init__('Zinc', 'Zn', 30, 65.38)


class Gallium(Element):
    def __init__(self):
        super().__init__('Gallium', 'Ga', 31, 69.723)


class Germanium(Element):
    def __init__(self):
        super().__init__('Germanium', 'Ge', 32, 72.63)


class Arsenic(Element):
    def __init__(self):
        super().__init__('Arsenic', 'As', 33, 74.921)


class Selenium(Element):
    def __init__(self):
        super().__init__('Selenium', 'Se', 34, 78.971)


class Bromine(Element):
    def __init__(self):
        super().__init__('Bromine', 'Br', 35, 79.901)


class Krypton(Element):
    def __init__(self):
        super().__init__('Krypton', 'Kr', 36, 83.798)


class Rubidium(Element):
    def __init__(self):
        super().__init__('Rubidium', 'Rb', 37, 85.4678)


class Strontium(Element):
    def __init__(self):
        super().__init__('Strontium', 'Sr', 38, 87.62)


class Yttrium(Element):
    def __init__(self):
        super().__init__('Yttrium', 'Y', 39, 88.905)


class Zirconium(Element):
    def __init__(self):
        super().__init__('Zirconium', 'Zr', 40, 91.224)


class Niobium(Element):
    def __init__(self):
        super().__init__('Niobium', 'Nb', 41, 92.906)


class Molybdenum(Element):
    def __init__(self):
        super().__init__('Molybdenum', 'Mo', 42, 95.95)


class Technetium(Element):
    def __init__(self):
        super().__init__('Technetium', 'Tc', 43, 98.0)


class Ruthenium(Element):
    def __init__(self):
        super().__init__('Ruthenium', 'Ru', 44, 101.07)


class Rhodium(Element):
    def __init__(self):
        super().__init__('Rhodium', 'Rh', 45, 102.905)


class Palladium(Element):
    def __init__(self):
        super().__init__('Palladium', 'Pd', 46, 106.42)


class Silver(Element):
    def __init__(self):
        super().__init__('Silver', 'Ag', 47, 107.8682)


class Cadmium(Element):
    def __init__(self):
        super().__init__('Cadmium', 'Cd', 48, 112.414)


class Indium(Element):
    def __init__(self):
        super().__init__('Indium', 'In', 49, 114.818)


class Tin(Element):
    def __init__(self):
        super().__init__('Tin', 'Sn', 50, 118.71)


class Antimony(Element):
    def __init__(self):
        super().__init__('Antimony', 'Sb', 51, 121.76)


class Tellurium(Element):
    def __init__(self):
        super().__init__('Tellurium', 'Te', 52, 127.6)


class Iodine(Element):
    def __init__(self):
        super().__init__('Iodine', 'I', 53, 126.904)


class Xenon(Element):
    def __init__(self):
        super().__init__('Xenon', 'Xe', 54, 131.293)


class Cesium(Element):
    def __init__(self):
        super().__init__('Cesium', 'Cs', 55, 132.905)


class Barium(Element):
    def __init__(self):
        super().__init__('Barium', 'Ba', 56, 137.327)


class Lanthanum(Element):
    def __init__(self):
        super().__init__('Lanthanum', 'La', 57, 138.905)


class Cerium(Element):
    def __init__(self):
        super().__init__('Cerium', 'Ce', 58, 140.116)


class Praseodymium(Element):
    def __init__(self):
        super().__init__('Praseodymium', 'Pr', 59, 140.907)


class Neodymium(Element):
    def __init__(self):
        super().__init__('Neodymium', 'Nd', 60, 144.242)


class Promethium(Element):
    def __init__(self):
        super().__init__('Promethium', 'Pm', 61, 145)


class Samarium(Element):
    def __init__(self):
        super().__init__('Samarium', 'Sm', 62, 150.36)


class Europium(Element):
    def __init__(self):
        super().__init__('Europium', 'Eu', 63, 151.964)


class Gadolinium(Element):
    def __init__(self):
        super().__init__('Gadolinium', 'Gd', 64, 157.25)


class Terbium(Element):
    def __init__(self):
        super().__init__('Terbium', 'Tb', 65, 158.925)


class Dysprosium(Element):
    def __init__(self):
        super().__init__('Dysprosium', 'Dy', 66, 162.5)


class Holmium(Element):
    def __init__(self):
        super().__init__('Holmium', 'Ho', 67, 164.93)


class Erbium(Element):
    def __init__(self):
        super().__init__('Erbium', 'Er', 68, 167.259)


class Thulium(Element):
    def __init__(self):
        super().__init__('Thulium', 'Tm', 69, 168.934)


class Ytterbium(Element):
    def __init__(self):
        super().__init__('Ytterbium', 'Yb', 70, 173.054)


class Lutetium(Element):
    def __init__(self):
        super().__init__('Lutetium', 'Lu', 71, 174.9668)


class Hafnium(Element):
    def __init__(self):
        super().__init__('Hafnium', 'Hf', 72, 178.49)


class Tantalum(Element):
    def __init__(self):
        super().__init__('Tantalum', 'Ta', 73, 180.947)


class Tungsten(Element):
    def __init__(self):
        super().__init__('Tungsten', 'W', 74, 183.84)


class Rhenium(Element):
    def __init__(self):
        super().__init__('Rhenium', 'Re', 75, 186.207)


class Osmium(Element):
    def __init__(self):
        super().__init__('Osmium', 'Os', 76, 190.23)


class Iridium(Element):
    def __init__(self):
        super().__init__('Iridium', 'Ir', 77, 192.217)


class Platinum(Element):
    def __init__(self):
        super().__init__('Platinum', 'Pt', 78, 195.084)


class Gold(Element):
    def __init__(self):
        super().__init__('Gold', 'Au', 79, 196.966)


class Mercury(Element):
    def __init__(self):
        super().__init__('Mercury', 'Hg', 80, 200.592)


class Thallium(Element):
    def __init__(self):
        super().__init__('Thallium', 'Tl', 81, 204.382)


class Lead(Element):
    def __init__(self):
        super().__init__('Lead', 'Pb', 82, 207.2)


class Bismuth(Element):
    def __init__(self):
        super().__init__('Bismuth', 'Bi', 83, 208.98)


class Polonium(Element):
    def __init__(self):
        super().__init__('Polonium', 'Po', 84, 209)


class Astatine(Element):
    def __init__(self):
        super().__init__('Astatine', 'At', 85, 210)


class Radon(Element):
    def __init__(self):
        super().__init__('Radon', 'Rn', 86, 222)


class Francium(Element):
    def __init__(self):
        super().__init__('Francium', 'Fr', 87, 223)


class Radon(Element):
    def __init__(self):
        super().__init__('Radon', 'Ra', 88, 226)


class Actinium(Element):
    def __init__(self):
        super().__init__('Actinium', 'Ac', 89, 227)


class Thorium(Element):
    def __init__(self):
        super().__init__('Thorium', 'Th', 90, 232.037)


class Protactinium(Element):
    def __init__(self):
        super().__init__('Protactinium', 'Pa', 91, 231.035)


class Uranium(Element):
    def __init__(self):
        super().__init__('Uranium', 'U', 92, 238.028)


class Neptunium(Element):
    def __init__(self):
        super().__init__('Neptunium', 'Np', 93, 237)


class Plutonium(Element):
    def __init__(self):
        super().__init__('Plutonium', 'Pu', 94, 244)


class Americium(Element):
    def __init__(self):
        super().__init__('Americium', 'Am', 95, 243)


class Curium(Element):
    def __init__(self):
        super().__init__('Curium', 'Cm', 96, 247)


class Berkelium(Element):
    def __init__(self):
        super().__init__('Berkelium', 'Bk', 97, 247)


class Californium(Element):
    def __init__(self):
        super().__init__('Californium', 'Cf', 98, 251)


class Einsteinium(Element):
    def __init__(self):
        super().__init__('Einsteinium', 'Es', 99, 252)


class Fermium(Element):
    def __init__(self):
        super().__init__('Fermium', 'Fm', 100, 257)


class Mendelevium(Element):
    def __init__(self):
        super().__init__('Mendelevium', 'Md', 101, 258)


class Nobelium(Element):
    def __init__(self):
        super().__init__('Nobelium', 'No', 102, 259)


class LawrenciumRutherfordium(Element):
    def __init__(self):
        super().__init__('LawrenciumRutherfordium', 'Lr', 103, 262)


class Dubnium(Element):
    def __init__(self):
        super().__init__('Dubnium', 'Rf', 104, 267)


class Seaborgium(Element):
    def __init__(self):
        super().__init__('Seaborgium', 'Db', 105, 268)


class Bohrium(Element):
    def __init__(self):
        super().__init__('Bohrium', 'Sg', 106, 271)


class Hassium(Element):
    def __init__(self):
        super().__init__('Hassium', 'Bh', 107, 272)


class Meitnerium(Element):
    def __init__(self):
        super().__init__('Meitnerium', 'Hs', 108, 270)


class Darmstadtium(Element):
    def __init__(self):
        super().__init__('Darmstadtium', 'Mt', 109, 276)


class Roentgenium(Element):
    def __init__(self):
        super().__init__('Roentgenium', 'Ds', 110, 281)


class Copernicium(Element):
    def __init__(self):
        super().__init__('Copernicium', 'Rg', 111, 280)


class Ununtrium(Element):
    def __init__(self):
        super().__init__('Ununtrium', 'Cn', 112, 285)


class Flerovium(Element):
    def __init__(self):
        super().__init__('Flerovium', 'Uut', 113, 284)


class Ununpentium(Element):
    def __init__(self):
        super().__init__('Ununpentium', 'Fl', 114, 289)


class Livermorium(Element):
    def __init__(self):
        super().__init__('Livermorium', 'Uup', 115, 288)


class Ununseptium(Element):
    def __init__(self):
        super().__init__('Ununseptium', 'Lv', 116, 293)


class Ununoctium(Element):
    def __init__(self):
        super().__init__('Ununoctium', 'Uus', 117, 294)

# %%
def element_subclasses_generator():
    name_data = ["Null", "Hydrogen", "Helium", "Lithium", "Beryllium", "Boron", "Carbon", "Nitrogen", "Oxygen", "Fluorine", "Neon", "Sodium", "Magnesium", "Aluminum", "Silicon", "Phosphorous", "Sulfur", "Chlorine", "Argon", "Potassium", "Calcium", "Scandium", "Titanium", "Vanadium", "Chromium", "Manganese", "Iron", "Cobalt", "Nickel", "Copper", "Zinc", "Gallium", "Germanium", "Arsenic", "Selenium", "Bromine", "Krypton", "Rubidium", "Strontium", "Yttrium", "Zirconium", "Niobium", "Molybdenum", "Technetium", "Ruthenium", "Rhodium", "Palladium", "Silver", "Cadmium", "Indium", "Tin", "Antimony", "Tellurium", "Iodine", "Xenon", "Cesium", "Barium", "Lanthanum", "Cerium", "Praseodymium", "Neodymium", "Promethium", "Samarium", "Europium", "Gadolinium", "Terbium", "Dysprosium", "Holmium", "Erbium", "Thulium", "Ytterbium", "Lutetium", "Hafnium", "Tantalum", "Tungsten", "Rhenium", "Osmium", "Iridium", "Platinum", "Gold", "Mercury", "Thallium", "Lead", "Bismuth", "Polonium", "Astatine", "Radon", "Francium", "Radon", "Actinium", "Thorium", "Protactinium", "Uranium", "Neptunium", "Plutonium", "Americium", "Curium", "Berkelium", "Californium", "Einsteinium", "Fermium", "Mendelevium", "Nobelium", "Lawrencium", "Rutherfordium", "Dubnium", "Seaborgium", "Bohrium", "Hassium", "Meitnerium", "Darmstadtium", "Roentgenium", "Copernicium", "Ununtrium", "Flerovium", "Ununpentium", "Livermorium", "Ununseptium", "Ununoctium"]
    mass_data = [0.0, 1.007, 4.002, 6.938, 9.012, 10.806, 12.0096, 14.006, 15.999, 18.998, 20.1797, 22.989, 24.304, 26.981, 28.084, 30.973, 32.059, 35.446, 39.948, 39.0983, 40.078, 44.955, 47.867, 50.9415, 51.9961, 54.938, 55.845, 58.933, 58.6934, 63.546, 65.38, 69.723, 72.630, 74.921, 78.971, 79.901, 83.798, 85.4678, 87.62, 88.905, 91.224, 92.906, 95.95, 98.0, 101.07, 102.905, 106.42, 107.8682, 112.414, 114.818, 118.710, 121.760, 127.60, 126.904, 131.293, 132.905, 137.327, 138.905, 140.116, 140.907, 144.242, 145, 150.36, 151.964, 157.25, 158.925, 162.500, 164.930, 167.259, 168.934, 173.054, 174.9668, 178.49, 180.947, 183.84, 186.207, 190.23, 192.217, 195.084, 196.966, 200.592, 204.382, 207.2, 208.980, 209, 210, 222, 223, 226, 227, 232.037, 231.035, 238.028, 237, 244, 243, 247, 247, 251, 252, 257, 258, 259, 262, 267, 268, 271, 272, 270, 276, 281, 280, 285, 284, 289, 288, 293, 294, 294]  
    symbol_data = ["done", "H", "He", "Li", "Be", "B", "C", "N", "O", "F", "Ne", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "Ar", "K", "Ca", "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Kr","Rb", "Sr", "Y", "Zr", "Nb", "Mo", "Tc", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I", "Xe", "Cs", "Ba", "La", "Ce", "Pr", "Nd", "Pm", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt", "Au", "Hg", "Tl", "Pb", "Bi", "Po", "At", "Rn", "Fr", "Ra", "Ac", "Th", "Pa", "U", "Np", "Pu", "Am", "Cm", "Bk", "Cf", "Es", "Fm", "Md", "No", "Lr", "Rf", "Db", "Sg", "Bh", "Hs", "Mt", "Ds", "Rg", "Cn", "Uut", "Fl", "Uup", "Lv", "Uus", "Uuo"]
    
    for index, name in enumerate(name_data):
        yield('class {}(Element):'.format(name) + '\n'+
        '    def __init__(self):' + '\n' +
        "        super().__init__('{}', '{}', {}, {})".format(name, symbol_data[index], index, mass_data[index]) + '\n' +
        "        self.label = ''" + '\n' + '\n')

# %%
#write something to write x number of elements to new .py file
# Out:
# 119

# %%
for i in range(5):
    print(next(subclasses))
# Out:
# class Zirconium(Element):
#     def __init__(self):
#         super().__init__('Zirconium', 'Zr', 40, 91.224)
#         self.label = ''
#
#
# class Niobium(Element):
#     def __init__(self):
#         super().__init__('Niobium', 'Nb', 41, 92.906)
#         self.label = ''
#
#
# class Molybdenum(Element):
#     def __init__(self):
#         super().__init__('Molybdenum', 'Mo', 42, 95.95)
#         self.label = ''
#
#
# class Technetium(Element):
#     def __init__(self):
#         super().__init__('Technetium', 'Tc', 43, 98.0)
#         self.label = ''
#
#
# class Ruthenium(Element):
#     def __init__(self):
#         super().__init__('Ruthenium', 'Ru', 44, 101.07)
#         self.label = ''

# %%
subclasses
# Out:
# <generator object element_subclasses_generator at 0x000002C028225F68>
